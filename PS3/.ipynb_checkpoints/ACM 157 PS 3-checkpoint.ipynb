# %%
import matplotlib.pyplot as plt
import numpy as np
from math import log, sqrt

# %% [markdown]
# # Problem 3a {-}

# %%
# Load data
data = np.loadtxt('../data/fiji.txt')
magnitudes = data[:,4]
n = len(magnitudes)

# Plot eCDF
mag_sorted = np.sort(magnitudes)
ranks = np.linspace(0, 1, n)
plt.plot(mag_sorted, ranks, label='eCDF')

# Plot confidence bands
alpha = 0.05
eps = sqrt((1 / (2 * n)) * log(2 / alpha))
plt.plot(mag_sorted, np.where(ranks - eps > 0, ranks - eps, 0), label='Confidence band (lowerbound)')
plt.plot(mag_sorted, np.where(ranks + eps < 1, ranks + eps, 1), label='Confidence band (upperbound)')

plt.title('Empirical CDF of magnitudes of seismic events in Fiji')
plt.xlabel('Magnitude')
plt.ylabel('Cumulative probability')
plt.legend()
plt.show()

# %% [markdown]
# # Problem 3b {-}

# %%
def piecewise_linear(x):
    if x not in
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-3d0ae8bff068> in <module>
# ----> 1 plt.plot(mag_sorted, np.piecewise(ranks), label='eCDF')
#
# TypeError: piecewise() missing 2 required positional arguments: 'condlist' and 'funclist'
